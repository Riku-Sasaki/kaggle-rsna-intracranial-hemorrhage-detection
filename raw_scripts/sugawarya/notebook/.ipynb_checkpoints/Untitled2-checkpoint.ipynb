# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import pandas as pd
import numpy as np
import pickle
from sklearn.metrics import log_loss
from tqdm import tqdm

# %%
train = pd.read_pickle('train_6model_fasterfeats.pickle')
test_list = pd.read_pickle('test_6models_fasterfeats.pickle')

# %%
target_cols = ['any', 'epidural', 'subdural', 'subarachnoid', 'intraventricular', 'intraparenchymal']
X_cols = train.columns.drop(['StudyInstanceUID', 'folds', 'ID'] + target_cols).tolist()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
X_train = []
X_valid = []
y_train = []
y_valid = []
std = MinMaxScaler()
std.fit(train.drop(['ID', 'StudyInstanceUID', 'folds'] + target_cols, axis=1).values)
for i in range(5):
    X_train.append(
        std.transform(train.query('folds!=@i').drop(['ID', 'StudyInstanceUID', 'folds'] + target_cols, axis=1).values)
    )
    X_valid.append(
        std.transform(train.query('folds==@i').drop(['ID', 'StudyInstanceUID', 'folds'] + target_cols, axis=1).values)
    )
    y_train.append(train.query('folds!=@i')[target_cols].values)
    y_valid.append(train.query('folds!=@i')[target_cols].values)

# %%
# X_train = np.array(X_train)#.transpose(1, 0, 2)[:, np.newaxis, ...]
# X_valid = np.array(X_valid)#.transpose(1, 0, 2)[:, np.newaxis, ...]

# %%
class StackingDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return self.X.shape[0]
    def __getitem__(self, idx):
        return torch.FloatTensor(self.X[idx]), torch.FloatTensor(self.y[idx])

# %%
for X_train_, X_valid_, y_train_, y_valid_ in zip(X_train, X_valid, y_train, y_valid):
    train_loader = DataLoader(
        StackingDataset(X_train_, y_train_),
        shuffle=True,
        batch_size=2048,
        num_workers=4,
        pin_memory=True,
    )
    valid_loader = DataLoader(
        StackingDataset(X_valid_, y_valid_),
        batch_size=2048,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    break

# %%
class MLPNet (nn.Module):
    def __init__(self):
        super(MLPNet, self).__init__()
        self.fc1 = nn.Linear(len(X_cols), 50)
        self.bn1 = nn.BatchNorm1d(50)
        self.fc2 = nn.Linear(50, 6)
#         self.fc3 = nn.Linear(512, 6)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.bn1(x)
        x = F.relu(self.fc2(x))
        return x
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = MLPNet().to(device)

# optimizing
criterion = nn.BCEWithLogitsLoss(weight=torch.FloatTensor([2, 1, 1, 1, 1, 1]).cuda())
optimizer = torch.optim.Adam(model.parameters(), 1e-3)

# %%
for epoch in range(10):
    losses = []
    for x, y in train_loader:
        pred = model(x.cuda())
        loss = criterion(pred, y.cuda())
        print(loss)
        if not np.isnan(loss.item()):
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            losses.append(loss.item())
    losses_valid = []
    with torch.no_grad():
        model.eval()
        for x, y in valid_loader:
            pred = model(x.cuda())
            loss = criterion(pred, y.cuda())
            losses_valid.append(loss.item())
    print(f'Epoch[{epoch}]', 'Train:', np.mean(losses), 'Valid:', np.mean(losses_valid))
    model.train()
# Out:
# tensor(0.9010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0
device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7806, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7785, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7753, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7749, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7844, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7839, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7857, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7770, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7764, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7763, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7774, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7802, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7812, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7811, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7843, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7816, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7755, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7830, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7756, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7807, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7791, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7747, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7815, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7840, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7808, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7875, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7779, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7839, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7761, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7872, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7756, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7825, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7763, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7794, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7801, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7844, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7762, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7772, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7779, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7761, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7806, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7731, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7762, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7731, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7853, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7859, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7771, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7802, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7783, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7775, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7777, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7813, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7852, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7820, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7819, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7779, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7811, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7816, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7825, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7748, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7766, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7778, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7791, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7861, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7807, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7801, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7778, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7772, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7777, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7813, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7787, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7754, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7757, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7837, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7844, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7810, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7758, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7735, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7878, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7788, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7807, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7796, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7785, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7791, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7761, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7760, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7792, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7811, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7856, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7731, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7825, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7763, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7812, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7829, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7821, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7823, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7773, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7772, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7765, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7847, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7774, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7748, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7761, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7753, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7784, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7802, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7794, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7814, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7734, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7802, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7768, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7782, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7750, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7854, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7752, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7807, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Epoch[1] Train: 0.7792653761315069 Valid: nan
# tensor(0.7759, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7757, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7770, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(nan, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7809, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7826, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7778, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7798, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7760, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7788, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7824, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7813, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7821, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7721, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7727, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7818, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7781, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7748, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7789, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7830, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7825, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7791, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7762, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7751, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7774, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7785, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7785, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7809, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7834, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7764, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7765, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7842, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7747, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7783, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7792, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# tensor(0.7765, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-56f1d7e1d563> in <module>
#       1 for epoch in range(10):
#       2     losses = []
# ----> 3     for x, y in train_loader:
#       4         pred = model(x.cuda())
#       5         loss = criterion(pred, y.cuda())
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self.shutdown and self.tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self.tasks_outstanding -= 1
#     806
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self.pin_memory:
#     760             while self.pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self.data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# /usr/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Out:
# torch.Size([512, 576])
